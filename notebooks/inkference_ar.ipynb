# %% [markdown]
# # Inkference AR – TrOCR Fine-Tuning on Bentham R0
#
# Fine-tuning of `microsoft/trocr-base-handwritten` on the Bentham R0 dataset (HTR).
# Metrics: Character Error Rate (CER) and Word Error Rate (WER).

# %% [markdown]
# ## Step 1 – Understand the Dataset

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

from pathlib import Path
import pandas as pd
from PIL import Image

ROOT      = Path("..")
GT_DIR    = ROOT / "data" / "BenthamDatasetR0-GT"
LINES_DIR = GT_DIR / "Images" / "Lines"
TRANS_DIR = GT_DIR / "Transcriptions"
PART_DIR  = GT_DIR / "Partitions"

print("Pfade vorhanden:")
for p in [GT_DIR, LINES_DIR, TRANS_DIR, PART_DIR]:
    print(f"  {'✓' if p.exists() else '✗'} {p}")
# Out:
# Pfade vorhanden:
#   ✓ ../data/BenthamDatasetR0-GT
#   ✓ ../data/BenthamDatasetR0-GT/Images/Lines
#   ✓ ../data/BenthamDatasetR0-GT/Transcriptions
#   ✓ ../data/BenthamDatasetR0-GT/Partitions

# %%
# Check number of samples per partition
for lst in ["TrainLines.lst", "ValidationLines.lst", "TestLines.lst"]:
    count = len((PART_DIR / lst).read_text().strip().splitlines())
    label = lst.replace("Lines.lst", "")
    print(f"{label:12s}: {count:>6} Zeilen")
# Out:
# Train       :   9198 Zeilen
# Validation  :   1415 Zeilen
# Test        :    860 Zeilen

# %%
# Sample: image size and mode (first 200 images)
img_files = sorted(LINES_DIR.glob("*.png"))[:200]
widths, heights, modes = [], [], set()

for f in img_files:
    img = Image.open(f)
    widths.append(img.size[0])
    heights.append(img.size[1])
    modes.add(img.mode)

print(f"Bildmodi   : {modes}  → wird zu RGB konvertiert")
print(f"Breite     : min={min(widths)}, max={max(widths)}, median={sorted(widths)[len(widths)//2]}")
print(f"Höhe       : min={min(heights)}, max={max(heights)}, median={sorted(heights)[len(heights)//2]}")
# Out:
# Bildmodi   : {'RGBA'}  → wird zu RGB konvertiert
# Breite     : min=49, max=2311, median=1631
# Höhe       : min=28, max=385, median=157

# %% [markdown]
# ## Step 2 – Link Image-Transcript Pairs
#
# Each image in `Images/Lines/` has a matching `.txt` file in `Transcriptions/`.
# We build a DataFrame with `image_path` and `transcription`.

# %%
records = []
for img_path in sorted(LINES_DIR.glob("*.png")):
    trans_path = TRANS_DIR / f"{img_path.stem}.txt"
    if trans_path.exists():
        transcription = trans_path.read_text(encoding="utf-8").strip()
        records.append({"image_path": str(img_path), "transcription": transcription})

df = pd.DataFrame(records)
print(f"Paare gesamt: {len(df)}")
df.head(10)
# Out:
# Paare gesamt: 11473
#                                           image_path  \
# 0  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 1  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 2  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 3  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 4  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 5  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 6  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 7  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 8  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
# 9  ../data/BenthamDatasetR0-GT/Images/Lines/002_0...
#
#                                        transcription
# 0                                                 36
# 1                                        16 Aug 1800
# 2  6 . The evidence of the engagement , consigned...
# 3  instrument , instead of a fixed Book .  _  Tak...
# 4  quer Bills , _  Differs from Stock Annuities  ...
# 5  Irish Debentures , and the now disused Navy Vi...
# 6  alling Transport and Ordnance Bills or Debentu...
# 7  also with India Bonds , Bank Notes , Banker ' ...
# 8  Notes ; and private Promissory Notes and Bills...
# 9  7 . The Paper , by its size , shape , texture ...

# %% [markdown]
# ## Step 3 – Load & Split Partitions
#
# The `.lst` files in `Partitions/` determine which lines belong to train, validation, and test.

# %%
def load_ids(lst_file):
    return set(Path(lst_file).read_text().strip().splitlines())

train_ids = load_ids(PART_DIR / "TrainLines.lst")
val_ids   = load_ids(PART_DIR / "ValidationLines.lst")
test_ids  = load_ids(PART_DIR / "TestLines.lst")

def assign_split(image_path):
    stem = Path(image_path).stem
    if stem in train_ids: return "train"
    if stem in val_ids:   return "val"
    if stem in test_ids:  return "test"
    return "unknown"

df["split"] = df["image_path"].apply(assign_split)

print(df["split"].value_counts().to_string())
print(f"\nUnbekannte Einträge: {(df['split'] == 'unknown').sum()}")
# Out:
# split
# train    9198
# val      1415
# test      860
#
# Unbekannte Einträge: 0

# %%
df_train = df[df["split"] == "train"].reset_index(drop=True)
df_val   = df[df["split"] == "val"].reset_index(drop=True)
df_test  = df[df["split"] == "test"].reset_index(drop=True)

print(f"Train : {len(df_train):>5} Zeilen")
print(f"Val   : {len(df_val):>5} Zeilen")
print(f"Test  : {len(df_test):>5} Zeilen")
# Out:
# Train :  9198 Zeilen
# Val   :  1415 Zeilen
# Test  :   860 Zeilen

# %% [markdown]
# ## Step 4 – Preprocess Images
#
# Images are in RGBA format. TrOCR expects RGB (3 channels).
# Resize (384 × 384) and normalisation are handled automatically by the `TrOCRProcessor`.

# %%
def load_image(image_path: str) -> Image.Image:
    """Load image and convert RGBA to RGB."""
    img = Image.open(image_path)
    if img.mode != "RGB":
        img = img.convert("RGB")
    return img

# Sanity check
sample_path = df_train.iloc[0]["image_path"]
img = load_image(sample_path)
print(f"Modus nach Konvertierung : {img.mode}")
print(f"Größe (original)         : {img.size}")
# Out:
# Modus nach Konvertierung : RGB
# Größe (original)         : (85, 71)

# %%
import matplotlib.pyplot as plt

# Visualise 8 random training lines
sample = df_train.sample(8, random_state=42).reset_index(drop=True)

fig, axes = plt.subplots(8, 1, figsize=(14, 12))
for ax, (_, row) in zip(axes, sample.iterrows()):
    img = load_image(row["image_path"])
    ax.imshow(img)
    ax.set_title(row["transcription"], fontsize=9, loc="left", pad=2)
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5 – Build Dataset Object
#
# The dataset connects our data to TrOCR:
# - Images are preprocessed by the `TrOCRProcessor` (resize to 384×384, normalisation)
# - Transcriptions are tokenised
# - Padding tokens in labels are set to `-100` (ignored in the loss)

# %%
from transformers import TrOCRProcessor

# Loads ViT-ImageProcessor + Tokenizer in one step
# First call downloads from HuggingFace and caches locally
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
print("Processor geladen.")
# Out:
# /home/justin/Ginger_Gradient/14/project/Capstone-Project/.venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processor geladen.

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class BenthamDataset(Dataset):
    def __init__(self, df, processor, max_target_length=128):
        self.df = df
        self.processor = processor
        self.max_target_length = max_target_length

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        # Load image and preprocess (resize + normalisation)
        img = load_image(row["image_path"])
        pixel_values = self.processor(images=img, return_tensors="pt").pixel_values.squeeze(0)

        # Tokenise transcription
        labels = self.processor.tokenizer(
            row["transcription"],
            padding="max_length",
            max_length=self.max_target_length,
            truncation=True,
            return_tensors="pt",
        ).input_ids.squeeze(0)

        # Replace padding token IDs with -100 → ignored in Cross-Entropy Loss
        labels[labels == self.processor.tokenizer.pad_token_id] = -100

        return {"pixel_values": pixel_values, "labels": labels}

# %%
# Instantiate datasets
train_dataset = BenthamDataset(df_train, processor)
val_dataset   = BenthamDataset(df_val,   processor)
test_dataset  = BenthamDataset(df_test,  processor)

# Check a single sample
sample = train_dataset[0]
print(f"pixel_values Shape : {sample['pixel_values'].shape}")   # expected: (3, 384, 384)
print(f"labels Shape       : {sample['labels'].shape}")         # expected: (128,)
print(f"labels (erste 10)  : {sample['labels'][:10].tolist()}")
# Out:
# pixel_values Shape : torch.Size([3, 384, 384])
# labels Shape       : torch.Size([128])
# labels (erste 10)  : [0, 3367, 2, -100, -100, -100, -100, -100, -100, -100]

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True,  num_workers=0)
val_loader   = DataLoader(val_dataset,   batch_size=16, shuffle=False, num_workers=0)

batch = next(iter(train_loader))
print(f"Batch pixel_values : {batch['pixel_values'].shape}")  # (16, 3, 384, 384)
print(f"Batch labels       : {batch['labels'].shape}")        # (16, 128)
print("DataLoader OK.")
# Out:
# Batch pixel_values : torch.Size([16, 3, 384, 384])
# Batch labels       : torch.Size([16, 128])
# DataLoader OK.

# %% [markdown]
# ## Step 6 – Load & Configure TrOCR
#
# - Model: `microsoft/trocr-base-handwritten` (pre-trained on handwriting)
# - Optimizer: AdamW with LR 1e-5
# - Scheduler: Linear Warmup (first 10% of steps) → then linear decay

# %%
from transformers import VisionEncoderDecoderModel

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# Decoder configuration
model.config.decoder_start_token_id = processor.tokenizer.cls_token_id
model.config.pad_token_id           = processor.tokenizer.pad_token_id
model.config.eos_token_id           = processor.tokenizer.sep_token_id

# Gradient checkpointing: saves ~60-70% VRAM at the cost of ~20% longer training time
model.config.use_cache = False
model.gradient_checkpointing_enable()

model.to(device)
print("Modell geladen. Gradient Checkpointing aktiv.")
# Out:
# Device: cuda
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-base-handwritten and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Modell geladen. Gradient Checkpointing aktiv.

# %%
from torch.optim import AdamW
from transformers import get_scheduler

EPOCHS        = 30
LEARNING_RATE = 1e-5   # reduced from 5e-5: model is pre-trained and already performs well
WARMUP_RATIO  = 0.1

total_steps  = EPOCHS * len(train_loader)
warmup_steps = int(total_steps * WARMUP_RATIO)

optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)

scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_steps,
)

print(f"Trainingsschritte gesamt : {total_steps}")
print(f"Warmup-Schritte          : {warmup_steps}")
print(f"Optimizer                : AdamW, LR={LEARNING_RATE}")
print(f"Scheduler                : Linear Warmup → Linear Decay")
# Out:
# Trainingsschritte gesamt : 17250
# Warmup-Schritte          : 1725
# Optimizer                : AdamW, LR=1e-05
# Scheduler                : Linear Warmup → Linear Decay

# %% [markdown]
# ## Step 7 – Training Loop
#
# Per epoch: train → measure validation CER → save checkpoint → check early stopping.
# Patience = 3 epochs without improvement in validation CER.

# %%
import evaluate

cer_metric = evaluate.load("cer")

def compute_cer(model, dataloader, processor, device):
    """Compute CER on a dataloader split."""
    model.eval()
    all_preds, all_refs = [], []

    with torch.no_grad():
        for batch in dataloader:
            pixel_values = batch["pixel_values"].to(device)
            labels        = batch["labels"].clone()

            generated_ids = model.generate(
                pixel_values,
                max_new_tokens=128,
            )
            preds = processor.batch_decode(generated_ids, skip_special_tokens=True)

            # replace -100 with pad_token_id so decode works
            labels[labels == -100] = processor.tokenizer.pad_token_id
            refs = processor.batch_decode(labels, skip_special_tokens=True)

            all_preds.extend(preds)
            all_refs.extend(refs)

    return cer_metric.compute(predictions=all_preds, references=all_refs)

# %%
from tqdm.notebook import tqdm
from torch.cuda.amp import GradScaler, autocast

PATIENCE       = 3
CHECKPOINT_DIR = Path("../checkpoints/best")
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)

best_cer         = float("inf")
patience_counter = 0
history          = []
scaler           = GradScaler()

if torch.cuda.is_available():
    torch.cuda.empty_cache()

for epoch in range(1, EPOCHS + 1):

    # ── Training ────────────────────────────────────────────────────────────
    model.train()
    total_loss = 0.0

    for batch in tqdm(train_loader, desc=f"Epoch {epoch:02d}/{EPOCHS} [train]", leave=False):
        pixel_values = batch["pixel_values"].to(device)
        labels       = batch["labels"].to(device)

        optimizer.zero_grad()

        with autocast():
            outputs = model(pixel_values=pixel_values, labels=labels)

        scaler.scale(outputs.loss).backward()
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()

        total_loss += outputs.loss.item()

    avg_loss = total_loss / len(train_loader)

    # ── Validation CER ──────────────────────────────────────────────────────
    val_cer = compute_cer(model, val_loader, processor, device)

    history.append({"epoch": epoch, "train_loss": avg_loss, "val_cer": val_cer})
    print(f"Epoch {epoch:02d} | Loss: {avg_loss:.4f} | Val CER: {val_cer:.4f}", end="")

    # ── Checkpoint & Early Stopping ─────────────────────────────────────────
    if val_cer < best_cer:
        best_cer         = val_cer
        patience_counter = 0
        model.save_pretrained(CHECKPOINT_DIR)
        processor.save_pretrained(CHECKPOINT_DIR)
        print(f"  ✓ Bestes Modell gespeichert")
    else:
        patience_counter += 1
        print(f"  ✗ Kein Fortschritt ({patience_counter}/{PATIENCE})")
        if patience_counter >= PATIENCE:
            print(f"\nEarly Stopping nach Epoche {epoch} — beste Val CER: {best_cer:.4f}")
            break
# Out:
# /tmp/ipykernel_19850/2835032504.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler           = GradScaler()
# Epoch 01/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 01 | Loss: 2.2890 | Val CER: 0.0975  ✓ Bestes Modell gespeichert
# Epoch 02/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 02 | Loss: 0.5624 | Val CER: 0.0544  ✓ Bestes Modell gespeichert
# Epoch 03/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 03 | Loss: 0.3581 | Val CER: 0.0439  ✓ Bestes Modell gespeichert
# Epoch 04/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 04 | Loss: 0.2341 | Val CER: 0.0372  ✓ Bestes Modell gespeichert
# Epoch 05/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 05 | Loss: 0.1630 | Val CER: 0.0346  ✓ Bestes Modell gespeichert
# Epoch 06/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 06 | Loss: 0.2304 | Val CER: 0.0392  ✗ Kein Fortschritt (1/3)
# Epoch 07/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# Epoch 07 | Loss: 0.1123 | Val CER: 0.0344  ✓ Bestes Modell gespeichert
# Epoch 08/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# /tmp/ipykernel_19850/2835032504.py:28: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 08 | Loss: 0.0773 | Val CER: 0.0349  ✗ Kein Fortschritt (1/3)
# Epoch 09/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# Epoch 09 | Loss: 0.0838 | Val CER: 0.0357  ✗ Kein Fortschritt (2/3)
# Epoch 10/30 [train]:   0%|          | 0/575 [00:00<?, ?it/s]
# Epoch 10 | Loss: 0.1260 | Val CER: 0.0381  ✗ Kein Fortschritt (3/3)
#
# Early Stopping nach Epoche 10 — beste Val CER: 0.0344

# %%
# Learning curve after training
history_df = pd.DataFrame(history)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(history_df["epoch"], history_df["train_loss"], marker="o")
ax1.set_title("Training Loss")
ax1.set_xlabel("Epoche")
ax1.set_ylabel("Loss")

ax2.plot(history_df["epoch"], history_df["val_cer"], marker="o", color="orange")
ax2.set_title("Validation CER")
ax2.set_xlabel("Epoche")
ax2.set_ylabel("CER")

plt.tight_layout()
plt.show()
print(f"\nBeste Validation CER: {history_df['val_cer'].min():.4f} (Epoche {history_df['val_cer'].idxmin() + 1})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Learning curve after training
# ----> 2 history_df = pd.DataFrame(history)
#       3
#       4 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
#       5
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Step 8 – Evaluation
#
# Load best checkpoint → CER & WER on the test set (quantitative) → sample predictions (qualitative).

# %%
import torch
import evaluate
from pathlib import Path
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
from transformers import VisionEncoderDecoderModel, TrOCRProcessor

device        = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CHECKPOINT_DIR = Path("../checkpoints/best")
cer_metric    = evaluate.load("cer")

# Load best checkpoint
best_model     = VisionEncoderDecoderModel.from_pretrained(CHECKPOINT_DIR).to(device)
best_processor = TrOCRProcessor.from_pretrained(CHECKPOINT_DIR)
best_model.eval()
print(f"Device           : {device}")
print(f"Checkpoint aus   : {CHECKPOINT_DIR}")
# Out:
# Device           : cuda
# Checkpoint aus   : ../checkpoints/best

# %%
wer_metric = evaluate.load("wer")

def compute_metrics(model, processor, df_split, device, batch_size=16):
    """Return CER, WER and all predictions."""
    dataset    = BenthamDataset(df_split, processor)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    all_preds, all_refs = [], []
    model.eval()

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating", leave=False):
            pixel_values = batch["pixel_values"].to(device)
            labels       = batch["labels"].clone()

            generated_ids = model.generate(pixel_values, max_new_tokens=128)
            preds = processor.batch_decode(generated_ids, skip_special_tokens=True)

            labels[labels == -100] = processor.tokenizer.pad_token_id
            refs = processor.batch_decode(labels, skip_special_tokens=True)

            all_preds.extend(preds)
            all_refs.extend(refs)

    cer = cer_metric.compute(predictions=all_preds, references=all_refs)
    wer = wer_metric.compute(predictions=all_preds, references=all_refs)
    return cer, wer, all_preds, all_refs

test_cer, test_wer, test_preds, test_refs = compute_metrics(
    best_model, best_processor, df_test, device
)

print(f"Test CER : {test_cer:.4f}  ({test_cer*100:.2f}%)")
print(f"Test WER : {test_wer:.4f}  ({test_wer*100:.2f}%)")
# Out:
# Evaluating:   0%|          | 0/54 [00:00<?, ?it/s]
# Test CER : 0.0390  (3.90%)
# Test WER : 0.1519  (15.19%)

# %%
# Qualitative examples: 10 random test lines with image, prediction and ground truth
sample_idx = df_test.sample(10, random_state=7).index.tolist()

fig, axes = plt.subplots(10, 1, figsize=(15, 18))
for ax, idx in zip(axes, sample_idx):
    img  = load_image(df_test.iloc[idx]["image_path"])
    pred = test_preds[idx]
    ref  = test_refs[idx]
    match = "✓" if pred.strip() == ref.strip() else "✗"
    ax.imshow(img)
    ax.set_title(
        f"{match}  GT  : {ref}\n   Pred: {pred}",
        fontsize=8, loc="left", pad=3, family="monospace"
    )
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# Error analysis: the 10 worst lines (highest character error)
from jiwer import cer as line_cer

errors = []
for idx, (pred, ref) in enumerate(zip(test_preds, test_refs)):
    if ref.strip():
        c = line_cer(ref, pred)
        errors.append((c, idx, ref, pred))

errors.sort(reverse=True)
print("Die 10 schlechtesten Predictions:\n")
for c, idx, ref, pred in errors[:10]:
    print(f"  CER {c:.2f} | GT  : {ref}")
    print(f"          | Pred: {pred}")
    print()
# Out:
# Die 10 schlechtesten Predictions:
#
#   CER 2.63 | GT  : Simple Of <gap/> Extenuations.
#           | Pred: Simple  <gap/>   <gap/>  <gap/>  <gap/>  <gap/>  <gap/>  <gap/>  <gap/>  <gap/>  <gap/>  <gap/>
#
#   CER 2.00 | GT  : 2
#           | Pred: 58
#
#   CER 1.00 | GT  : 7
#           | Pred: 1
#
#   CER 1.00 | GT  : a
#           | Pred: 9
#
#   CER 1.00 | GT  : 9
#           | Pred: 2
#
#   CER 1.00 | GT  : 107
#           | Pred: Boy
#
#   CER 1.00 | GT  : e
#           | Pred: 2
#
#   CER 1.00 | GT  : (C)
#           | Pred: ( c )
#
#   CER 1.00 | GT  : B
#           | Pred: 3
#
#   CER 1.00 | GT  : G
#           | Pred: C
